# %% [markdown]
# <div style="display: flex; justify-content: center; width: 100%;">
#     <div style="
#         background-color: gold;
#         color: black;
#         border: 1.5px solid black;
#         padding: 15px 30px;
#         border-radius: 10px;
#         max-width: 50vw;
#         text-align: center;
#         font-family: Arial, sans-serif;
#     ">
#         <h2 style="margin: 0;"><b>A New Approach to Music: Objectifying Composition</b></h2>
#     </div>
# </div>

# %% [markdown]
# Google Doc: https://docs.google.com/document/d/1Iq2mGACpDzneGAEn75G9QZjEmeM_e2lhZoqdENd1BWI/edit?usp=sharing
#
# ### **KEY AXIOMS AND DEFINITIONS**
#
# **Axiom 1.** Every active voice in a sonority contributes to the listener's perception of musical structure.
#
# **Definition 1.** For standardization, let the total sound of any musical entity (note, chord, etc.) be 1.

# %% [markdown]
# ### **METHODOLOGY**
#
# When considering a musical entity, one must consider the parameters in which we can determine how loud/soft one note in the entity is in relation to other notes inside this entity.
#
# Hence, the components of any musical entity can be represented by a vector with components that represent the $n^{th}$ note's relative balance.
#
# Let the Voice Balancing Vector (VBV) be denoted with the vector $\vec{b}$, where $b_1, b_2, b_3 ...  b_n$ are the $n$ notes in the musical entity from top down.
#
# Then:
# $$
# \vec{b} = \begin{bmatrix}
#                 b_1 \\
#                 b_2 \\
#                 b_3 \\
#                 \vdots \\
#                 b_n
#             \end{bmatrix}
# $$

# %% [markdown]
# ### **Beethoven Sonata Op. 111, First Movement Example**
#
# Using this method, I will analyze the first movement of Beethoven's Sonata Op. 111 using Python's music21.

# %%
from music21 import converter
score = converter.parse("data/beethoven_111.mxl")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/music21/musicxml/xmlToM21.py:2240: MusicXMLWarning: Warning: measure 1 in part Pianois overfull: 641/160 > 4.0,assuming 4.0 is correct.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/music21/musicxml/xmlToM21.py:2240: MusicXMLWarning: Warning: measure 3 in part Pianois overfull: 641/160 > 4.0,assuming 4.0 is correct.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/music21/musicxml/xmlToM21.py:2240: MusicXMLWarning: Warning: measure 5 in part Pianois overfull: 641/160 > 4.0,assuming 4.0 is correct.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/music21/musicxml/xmlToM21.py:5491: MusicXMLWarning: Could not import wedge: Error in getting DynamicWedges
#   warnings.warn(f'Could not import {tag}: {excep}', MusicXMLWarning)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/music21/musicxml/xmlToM21.py:2240: MusicXMLWarning: Warning: measure 119 in part Pianois overfull: 4.03125 > 4.0,assuming 4.0 is correct.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/music21/musicxml/xmlToM21.py:5491: MusicXMLWarning: Could not import pedal: Error in getting PedalMark
#   warnings.warn(f'Could not import {tag}: {excep}', MusicXMLWarning)
